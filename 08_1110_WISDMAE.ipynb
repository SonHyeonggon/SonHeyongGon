# %%
# 1. wisdm dataset(sitting 4500, running 4500)
# 3. sitting train, sitting + running test

# %%
# 필요한 라이브러리 로드
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense, Dropout
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %%
names = ['user-id', 'activity', 'timestamp', 'X', 'Y', 'Z']

df = pd.read_csv('D:/Son/3-2/deeplearning/report/dataset/WISDM/WISDM.csv', index_col=0)

def convert_to_float(x):
    try:
        return np.float(x)
    except:
        return np.nan

df["Z"].replace(regex = True, inplace = True, to_replace = r';', value = r'')
    # ... and then this column must be transformed to float explicitly
df["Z"] = df["Z"].apply(convert_to_float)
    # This is very important otherwise the model will not fit and loss will show up as NAN
df.dropna(axis=0, how='any', inplace=True)
df.info()
# Out:
# C:\Users\gudrh\AppData\Local\Temp\ipykernel_25204\2062605742.py:7: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return np.float(x)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1098203 entries, 0 to 1098203
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user-id    1098203 non-null  int64
#  1   activity   1098203 non-null  object
#  2   timestamp  1098203 non-null  int64
#  3   X          1098203 non-null  float64
#  4   Y          1098203 non-null  float64
#  5   Z          1098203 non-null  float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 58.7+ MB

# %%
plt.figure(figsize=(15, 5))

plt.xlabel('Activity Type')
plt.ylabel('Training examples')
df['activity'].value_counts().plot(kind='bar',
                                  title='Training examples by Activity Types')
plt.show()

plt.figure(figsize=(15, 5))
plt.xlabel('User')
plt.ylabel('Training examples')
df['user-id'].value_counts().plot(kind='bar', 
                                 title='Training examples by user')
plt.show()

# %%
df_sit = df[df['activity'] == 'Sitting']
df_run = df[df['activity'] == 'Jogging']

# %%
df_sit
# Out:
#          user-id activity        timestamp     X     Y         Z
# 221333        27  Sitting   12363992261000  2.60  9.66  1.035146
# 221334        27  Sitting   12364042279000  2.68  9.53  0.503953
# 221335        27  Sitting   12364092267000  3.49  8.89  0.762740
# 221336        27  Sitting   12364142316000  3.64  9.38  0.926184
# 221337        27  Sitting   12364192273000  2.91  9.34  1.035146
# ...          ...      ...              ...   ...   ...       ...
# 1098199       19  Sitting  131623331483000  9.00 -1.57  1.690000
# 1098200       19  Sitting  131623371431000  9.04 -1.46  1.730000
# 1098201       19  Sitting  131623411592000  9.08 -1.38  1.690000
# 1098202       19  Sitting  131623491487000  9.00 -1.46  1.730000
# 1098203       19  Sitting  131623531465000  8.88 -1.33  1.610000
#
# [59939 rows x 6 columns]

# %%
df_run
# Out:
#          user-id activity        timestamp          X          Y         Z
# 0             33  Jogging   49105962326000  -0.694638  12.680544  0.503953
# 1             33  Jogging   49106062271000   5.012288  11.264028  0.953424
# 2             33  Jogging   49106112167000   4.903325  10.882658 -0.081722
# 3             33  Jogging   49106222305000  -0.612916  18.496431  3.023717
# 4             33  Jogging   49106332290000  -1.184970  12.108489  7.205164
# ...          ...      ...              ...        ...        ...       ...
# 1080754       19  Jogging  130447441469000  -7.010000 -10.530000  0.570000
# 1080755       19  Jogging  130447481508000  -6.360000  -3.910000 -0.420000
# 1080756       19  Jogging  130447521547000 -11.260000   3.020000  1.570000
# 1080757       19  Jogging  130447561678000 -17.540000   4.670000  3.980000
# 1080758       19  Jogging  130447632570000 -11.260000  -0.500000  7.400000
#
# [342176 rows x 6 columns]

# %%
df_sit_sample = df_sit.head(4500).copy()

# %%
df_sit_sample
# Out:
#         user-id activity       timestamp     X     Y         Z
# 221333       27  Sitting  12363992261000  2.60  9.66  1.035146
# 221334       27  Sitting  12364042279000  2.68  9.53  0.503953
# 221335       27  Sitting  12364092267000  3.49  8.89  0.762740
# 221336       27  Sitting  12364142316000  3.64  9.38  0.926184
# 221337       27  Sitting  12364192273000  2.91  9.34  1.035146
# ...         ...      ...             ...   ...   ...       ...
# 255294       36  Sitting  14927622266000 -4.33 -2.18  8.308413
# 255295       36  Sitting  14927672254000 -4.37 -2.22  8.349273
# 255296       36  Sitting  14927722272000 -4.29 -2.22  8.308413
# 255297       36  Sitting  14927772199000 -4.29 -2.22  8.281172
# 255298       36  Sitting  14927822309000 -4.25 -2.18  8.349273
#
# [4500 rows x 6 columns]

# %%
df_run_sample = df_run.head(4500).copy()

# %%
df_run_sample
# Out:
#        user-id activity       timestamp         X          Y         Z
# 0           33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1           33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2           33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3           33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4           33  Jogging  49106332290000 -1.184970  12.108489  7.205164
# ...        ...      ...             ...       ...        ...       ...
# 13015       17  Jogging  58401032305000  5.434519   8.853226  3.909040
# 13016       17  Jogging  58401203050000 -4.331271  19.531578 -1.729784
# 13017       17  Jogging  58401432238000 -1.035146  -5.012288 -4.481094
# 13018       17  Jogging  58401542223000  7.082581  17.243360 -0.381370
# 13019       17  Jogging  58401592394000  6.442424   5.053149 -5.788648
#
# [4500 rows x 6 columns]

# %%
data = pd.concat([df_sit_sample, df_run_sample])

# %%
data
# Out:
#         user-id activity       timestamp         X          Y         Z
# 221333       27  Sitting  12363992261000  2.600000   9.660000  1.035146
# 221334       27  Sitting  12364042279000  2.680000   9.530000  0.503953
# 221335       27  Sitting  12364092267000  3.490000   8.890000  0.762740
# 221336       27  Sitting  12364142316000  3.640000   9.380000  0.926184
# 221337       27  Sitting  12364192273000  2.910000   9.340000  1.035146
# ...         ...      ...             ...       ...        ...       ...
# 13015        17  Jogging  58401032305000  5.434519   8.853226  3.909040
# 13016        17  Jogging  58401203050000 -4.331271  19.531578 -1.729784
# 13017        17  Jogging  58401432238000 -1.035146  -5.012288 -4.481094
# 13018        17  Jogging  58401542223000  7.082581  17.243360 -0.381370
# 13019        17  Jogging  58401592394000  6.442424   5.053149 -5.788648
#
# [9000 rows x 6 columns]

# %%
data = data.drop(['user-id','timestamp'], axis = 1)

# %%
data
# Out:
#        activity         X          Y         Z
# 221333  Sitting  2.600000   9.660000  1.035146
# 221334  Sitting  2.680000   9.530000  0.503953
# 221335  Sitting  3.490000   8.890000  0.762740
# 221336  Sitting  3.640000   9.380000  0.926184
# 221337  Sitting  2.910000   9.340000  1.035146
# ...         ...       ...        ...       ...
# 13015   Jogging  5.434519   8.853226  3.909040
# 13016   Jogging -4.331271  19.531578 -1.729784
# 13017   Jogging -1.035146  -5.012288 -4.481094
# 13018   Jogging  7.082581  17.243360 -0.381370
# 13019   Jogging  6.442424   5.053149 -5.788648
#
# [9000 rows x 4 columns]

# %%
from sklearn.preprocessing import LabelEncoder



le=LabelEncoder()

data['activity']=le.fit_transform(data['activity'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9000 entries, 221333 to 13019
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   activity  9000 non-null   int32
#  1   X         9000 non-null   float64
#  2   Y         9000 non-null   float64
#  3   Z         9000 non-null   float64
# dtypes: float64(3), int32(1)
# memory usage: 316.4 KB

# %%
df_train, df_test = train_test_split(data, test_size=0.25, random_state=1)

# %%
df_train = df_train[df_train['activity']==0]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3365 entries, 8048 to 5656
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   activity  3365 non-null   int32
#  1   X         3365 non-null   float64
#  2   Y         3365 non-null   float64
#  3   Z         3365 non-null   float64
# dtypes: float64(3), int32(1)
# memory usage: 118.3 KB

# %%
x_train = df_train.drop(['activity'], axis=1)

# %%
x_train
# Out:
#                X          Y          Z
# 8048    3.786457  14.900661   5.284695
# 5637   -8.580819  13.375181   3.636633
# 7964   -2.792171   8.621680   4.671779
# 6937   -1.797886  11.032481   6.660350
# 6047    1.225831  16.698545  12.408136
# ...          ...        ...        ...
# 5860  -11.073342  19.572440   0.272407
# 11771  -2.410802   3.377846  -5.625204
# 556    -5.666065  19.422615   9.575105
# 11833   9.003050   8.921328  -2.751310
# 5656   12.149350   8.008764  -4.985047
#
# [3365 rows x 3 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# MinMaxScaler 선언 및 Fitting
mMscaler = MinMaxScaler()
mMscaler.fit(x_train)

# 데이터 변환
x_train_scaling = mMscaler.transform(x_train)

# 데이터 프레임으로 저장
x_train = pd.DataFrame(x_train_scaling)

# %%
x_train
# Out:
#              0         1         2
# 0     0.562447  0.858498  0.650634
# 1     0.176720  0.812294  0.597726
# 2     0.357264  0.668317  0.630958
# 3     0.388275  0.741337  0.694797
# 4     0.482583  0.912954  0.879318
# ...        ...       ...       ...
# 3360  0.098980  1.000000  0.489725
# 3361  0.369159  0.509488  0.300394
# 3362  0.267630  0.995462  0.788369
# 3363  0.725149  0.677393  0.392654
# 3364  0.823280  0.649752  0.320944
#
# [3365 rows x 3 columns]

# %%
y_test = df_test['activity']
x_test = df_test.drop(['activity'],axis=1)

# %%
y_test
# Out:
# 5685      0
# 253774    1
# 6829      0
# 12611     0
# 222654    1
#          ..
# 254666    1
# 253910    1
# 223142    1
# 8345      0
# 253319    1
# Name: activity, Length: 2250, dtype: int32

# %%
x_test
# Out:
#                 X          Y         Z
# 5685     6.510526  14.328606  8.471856
# 253774  -4.790000  -2.260000  7.927042
# 6829     6.932757  17.311462 -3.064578
# 12611   10.501288  16.698545  1.838747
# 222654   3.340000   9.300000  1.076008
# ...           ...        ...       ...
# 254666  -4.290000  -2.260000  8.199450
# 253910  -4.560000  -2.070000  8.199450
# 223142   3.170000   9.300000  1.116869
# 8345    -5.012288  11.182305  5.475380
# 253319  -5.010000  -2.260000  7.886181
#
# [2250 rows x 3 columns]

# %%
input_dim = x_train.shape[1]
encoding_dim = 20
input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim/2, activation="relu", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim/2 ), activation='relu')(encoder)
encoder = Dense(int(encoding_dim/4 ), activation='relu')(encoder)
encoder = Dense(int(encoding_dim / 6), activation='linear')(encoder)
decoder = Dense(int(encoding_dim/4 ), activation='relu')(encoder)
decoder = Dense(int(encoding_dim/2 ), activation='relu')(decoder)
decoder = Dense(int(encoding_dim/2 ), activation='relu')(decoder)
decoder = Dense(input_dim, activation='linear')(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3)]               0
#
#  dense (Dense)               (None, 10)                40
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 5)                 55
#
#  dense_3 (Dense)             (None, 3)                 18
#
#  dense_4 (Dense)             (None, 5)                 20
#
#  dense_5 (Dense)             (None, 10)                60
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 3)                 33
#
# =================================================================
# Total params: 446
# Trainable params: 446
# Non-trainable params: 0
# _________________________________________________________________

# %%
#nb_epoch = 100
nb_epoch = 20
batch_size = 16
autoencoder.compile(optimizer='Adam', 
                    loss='mean_squared_error',
                    metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)
history = autoencoder.fit(x_train, x_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_split=0.1,
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/20
# 190/190 [==============================] - 2s 4ms/step - loss: 0.1450 - accuracy: 0.2850 - val_loss: 0.0234 - val_accuracy: 0.5786
# Epoch 2/20
# 190/190 [==============================] - 0s 3ms/step - loss: 0.0188 - accuracy: 0.6248 - val_loss: 0.0145 - val_accuracy: 0.7359
# Epoch 3/20
# 190/190 [==============================] - 0s 3ms/step - loss: 0.0115 - accuracy: 0.7698 - val_loss: 0.0120 - val_accuracy: 0.7804
# Epoch 4/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 0.7787 - val_loss: 0.0110 - val_accuracy: 0.7567
# Epoch 5/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.7457 - val_loss: 0.0102 - val_accuracy: 0.7418
# Epoch 6/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.7662 - val_loss: 0.0092 - val_accuracy: 0.7982
# Epoch 7/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.7876 - val_loss: 0.0076 - val_accuracy: 0.8190
# Epoch 8/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.8131 - val_loss: 0.0064 - val_accuracy: 0.8516
# Epoch 9/20
# 190/190 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.8395 - val_loss: 0.0059 - val_accuracy: 0.8961
# Epoch 10/20
# 190/190 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.8580 - val_loss: 0.0059 - val_accuracy: 0.8991
# Epoch 11/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 0.8587 - val_loss: 0.0058 - val_accuracy: 0.8961
# Epoch 12/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0054 - accuracy: 0.8636 - val_loss: 0.0059 - val_accuracy: 0.8932
# Epoch 13/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.8682 - val_loss: 0.0060 - val_accuracy: 0.8902
# Epoch 14/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.8696 - val_loss: 0.0058 - val_accuracy: 0.8961
# Epoch 15/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.8732 - val_loss: 0.0059 - val_accuracy: 0.8991
# Epoch 16/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.8771 - val_loss: 0.0058 - val_accuracy: 0.9021
# Epoch 17/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0052 - accuracy: 0.8762 - val_loss: 0.0059 - val_accuracy: 0.8961
# Epoch 18/20
# 190/190 [==============================] - 1s 3ms/step - loss: 0.0052 - accuracy: 0.8795 - val_loss: 0.0058 - val_accuracy: 0.8932
# Epoch 19/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 0.8798 - val_loss: 0.0057 - val_accuracy: 0.8991
# Epoch 20/20
# 190/190 [==============================] - 0s 2ms/step - loss: 0.0051 - accuracy: 0.8821 - val_loss: 0.0057 - val_accuracy: 0.8932

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
predictions = autoencoder.predict(x_test)
mse = np.mean(np.power(x_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})
error_df.describe()
# Out:
# 71/71 [==============================] - 0s 900us/step
#        reconstruction_error   true_class
# count           2250.000000  2250.000000
# mean              16.471722     0.495556
# std               17.422386     0.500091
# min                0.049649     0.000000
# 25%                0.900632     0.000000
# 50%                8.301429     0.000000
# 75%               34.838192     1.000000
# max              165.284193     1.000000

# %%
error_df.true_class.value_counts()
# Out:
# 0    1135
# 1    1115
# Name: true_class, dtype: int64

# %% [markdown]
# # ROC 곡선을 통한 평가

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
#평가관련
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
import seaborn as sns

LABELS = ["Normal", "AbNormal"]
threshold = 1


y_pred = [0 if e > threshold else 1 for e in error_df.reconstruction_error.values]

conf_matrix = confusion_matrix(error_df.true_class, y_pred)

plt.figure(figsize=(12, 12))

sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");

plt.title("Confusion matrix")

plt.ylabel('True class')

plt.xlabel('Predicted class')

plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support

from sklearn.metrics import accuracy_score

precision, recall, f1,_ = precision_recall_fscore_support(y_test,y_pred,average='binary')

print ('Accuracy Score :',accuracy_score(error_df.true_class, y_pred) )

print ('Precision :',precision )

print ('Recall :',recall )

print ('F1 :',f1 )
# Out:
# Accuracy Score : 0.7057777777777777
# Precision : 0.8980667838312829
# Recall : 0.45829596412556056
# F1 : 0.6068883610451307
